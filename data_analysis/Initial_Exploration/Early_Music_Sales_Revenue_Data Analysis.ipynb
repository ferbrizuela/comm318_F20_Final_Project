# %%
import pandas as pd
import warnings 
warnings.filterwarnings('ignore')

# %%
revenue_df = pd.read_csv('../../data/Old_Data/Music_Sales_Revenue_Data.csv')

# %% [markdown]
# ## Early analysis with old data.

# %%
revenue_df.shape
revenue_nrows = revenue_df.shape[0]
revenue_ncols = revenue_df.shape[1]

revenue_nrows, revenue_ncols = revenue_df.shape

print(f'There are {revenue_nrows} rows and {revenue_ncols} columns in the Music Sales Revenue data frame')
# Out:
# There are 286 rows and 16 columns in the Music Sales Revenue data frame

# %%
revenue_df
# Out:
#      Year of Year Date  Adjusted for Inflation Notes  \
# 0                 2000                           NaN
# 1                 2001                           NaN
# 2                 2002                           NaN
# 3                 2003                           NaN
# 4                 2004                           NaN
# ..                 ...                           ...
# 281               2015                           NaN
# 282               2016                           NaN
# 283               2017                           NaN
# 284               2018                           NaN
# 285               2019                           NaN
#
#      Adjusted for Inflation Title        Format Metric  Year  \
# 0                             NaN            CD  Value  2000
# 1                             NaN            CD  Value  2001
# 2                             NaN            CD  Value  2002
# 3                             NaN            CD  Value  2003
# ...

# %%
revenue_df.columns
# Out:
# Index(['Year of Year Date', 'Adjusted for Inflation Notes',
#        'Adjusted for Inflation Title', 'Format', 'Metric', 'Year',
#        'Value (For Charting)', 'Adjusted for Inflation Flag', 'Year Date',
#        'Format Value # (Billion)', 'Format Value # (Million)',
#        'Total Value # (Billion)', 'Total Value # (Million)',
#        'Total Value For Year', 'Value (Actual)', 'Year (copy)'],
#       dtype='object')

# %% [markdown]
# ### Observations
#
# * Similar to Sales Volume data frame, will have to make adjustments to columns.
# * Can remove some of the columns as the data is not available
# * I see that these rows are also divided in terms of format, I wonder whether I should look into how much revenue each format contributes each year.

# %%
revenue_df['Year'].value_counts()
# Out:
# 2019    19
# 2017    19
# 2016    19
# 2018    19
# 2012    16
# 2011    16
# 2009    16
# 2014    16
# 2015    16
# 2013    15
# 2010    15
# 2008    15
# 2007    15
# 2006    15
# 2005    15
# 2004    11
# 2003     8
# 2002     7
# 2001     7
# 2000     7
# Name: Year, dtype: int64

# %% [markdown]
# ### Observations
#
# I assumed the value counts would be the same as the other data set in terms of format.
